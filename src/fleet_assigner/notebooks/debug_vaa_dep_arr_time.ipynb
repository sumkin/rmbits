# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-rmp-home/nrm/bif/2023/05/INV_20230502.csv.gz")

# %%
df[
    (df["ORGN"] == "HEL") & 
    (df["DSTN"] == "PRG") & 
    (df["DEPDT"] == 20230605)
]
# Out:
#        CC  FLTNUM     DEPDT  DEPTM  DEPDT_UTC  DEPTM_UTC     ARRDT  ARRTM  \
# 63791  AY    1221  20230605    940   20230605        740  20230605   1050
# 63792  AY    1221  20230605    940   20230605        740  20230605   1050
# 63805  AY    1223  20230605   1735   20230605       1535  20230605   1845
# 63806  AY    1223  20230605   1735   20230605       1535  20230605   1845
# 63818  AY    1227  20230605    620   20230605        420  20230605    730
# 63819  AY    1227  20230605    620   20230605        420  20230605    730
#
#        ARRDT_UTC  ARRTM_UTC  ... CAPO CAPE  BKC  ETB  RC  EGS    AMR   RCR  \
# 63791   20230605        950  ...   16   32    2    5  RY    0  100.0  16.7
# 63792   20230605        950  ...  150  158  118  158  RY   90  100.0   0.9
# 63805   20230605       1745  ...   16   36    3    6  RY    0  100.0   3.9
# 63806   20230605       1745  ...  120  128   90  127  RY  306  100.0   0.8
# ...
