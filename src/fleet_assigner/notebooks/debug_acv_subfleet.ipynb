# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-emr-job/fleet_assigner/june2023/acv_subfleet.csv", sep = ";")

# %%
df.head(50)
# Out:
#     acv subfleet
# 0   A70      A70
# 1   A7A      A7A
# 2   E90      E90
# 3   319      319
# 4   320      320
# 5   321      321
# 6   32B      32B
# 7   32G      32G
# 8   32I      32I
# 9   33B      33B
# 10  33S      33S
# 11  35A      35A
# 12  35B      35B
# 13  35L      35L
# 14  35S      35S
# 15  29A      29A
# 16  DH4      DH4
# 17  21B      32B
# 18  21C      32B
# 19  21C      32G
# 20  21R      32B
# 21  21R      32G
# 22  21S      32B
# 23  21S      32G
# 24  21T      32B
# 25  21T      32G
# 26  31E      319
# 27  31X      319
# 28  32E      320
# 29  32L      321
# 30  32Y      320
# 31  32Z      321
# 32  33T      33S
# 33  N72      E90
# 34  N73      E90
# 35  N74      E90
# 36  N7A      A7A
# 37  WF1      29A
# 38  WF8      DH4
# 39  WFG      DH4
# 40  WFX      29A
# 41  35M      35L
# 42  35N      35L
# 43  35T      35S
# 44  35U      35S
# 45  35W      35B
# 46  35Y      35A
