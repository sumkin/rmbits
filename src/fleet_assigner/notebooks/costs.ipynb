# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-rmp-home/fleet_assigner/costs.csv")

# %%
df["TARGET_AIRCRAFT"].unique()
# Out:
# array(['359', '321', '32B', '320', 'AT7', '319', '333'], dtype=object)

# %%
df[
    (df["DEPARTURE"] == "HEL") &
    (df["ARRIVAL"] == "JFK") &
    (df["DATE_OF_FLIGHT"] == "2022-04-01") &
    (df["FLIGHT_NUMBER"] == 5)
].head(10)
# Out:
#     FLIGHT_NUMBER DEPARTURE ARRIVAL DATE_OF_FLIGHT TARGET_AIRCRAFT  \
# 7               5       HEL     JFK     2022-04-01             359
# 8               5       HEL     JFK     2022-04-01             321
# 9               5       HEL     JFK     2022-04-01             32B
# 10              5       HEL     JFK     2022-04-01             320
# 11              5       HEL     JFK     2022-04-01             AT7
# 12              5       HEL     JFK     2022-04-01             319
# 13              5       HEL     JFK     2022-04-01             333
#
#     PREDICTED_COST
# 7        132020.68
# 8        628690.03
# 9         99839.16
# 10        92064.83
# 11       105775.63
# 12        85847.16
# 13       214224.04
