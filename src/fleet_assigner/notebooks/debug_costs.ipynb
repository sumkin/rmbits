# %%
import pandas as pd

# %%
df_lines = pd.read_csv("../data/lines_partial.csv")
df_costs = pd.read_csv("s3://ay-emr-job/fleet_assigner/june2023/costs.csv")
df_costs["FLTNUM"] = df_costs["FLIGHT_NUMBER"]
df_costs["ORGN"] = df_costs["DEPARTURE"]
df_costs["DSTN"] = df_costs["ARRIVAL"]
df_costs["DEPDT"] = df_costs["DATE_OF_FLIGHT"]

# %%
df_lines.head(5)
# Out:
#   ORGN DSTN  FLTNUM     DEPDT     ARRDT  DEPTM  ARRTM AC_TYPE  AIRCRAFT_ID  \
# 0  HEL  JOE     341  20230601  20230601  04:35  05:40     A7A            1
# 1  JOE  HEL     342  20230601  20230601  06:00  07:05     A7A            1
# 2  HEL  KUO     369  20230601  20230601  14:25  15:25     A7A            1
# 3  KUO  HEL     370  20230601  20230601  15:50  16:50     A7A            1
# 4  HEL  KAJ     413  20230601  20230601  08:00  09:20     A7A            2
#
#     LINE     COSTS
# 0  A7A/1  41454.13
# 1  A7A/1  41454.13
# 2  A7A/1  41454.13
# 3  A7A/1  41454.13
# 4  A7A/2  41454.13

# %%
df_lines["COSTS"].sum()
# Out:
# 7394715.0200000005
