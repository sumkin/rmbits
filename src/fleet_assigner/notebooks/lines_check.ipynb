# %%
import pandas as pd

# %%
df = pd.read_csv("../data/lines.csv")

# %%
df[(df["LINE"] == "319/1")].sort_values(by = ["DEPDT","DEPTM"]).head(50)
# Out:
#    ORGN DSTN  FLTNUM     DEPDT     ARRDT  DEPTM  ARRTM AC_TYPE  AIRCRAFT_ID  \
# 0   HEL  GZP    1933  20220401  20220401  03:30  07:15     319            1
# 1   GZP  HEL    1934  20220401  20220401  08:05  11:55     319            1
# 2   HEL  ARN     813  20220401  20220401  12:55  13:55     319            1
# 3   ARN  HEL     814  20220401  20220401  14:35  15:35     319            1
# 4   HEL  LHR    1339  20220401  20220401  16:30  19:40     319            1
# 5   LHR  HEL    1340  20220402  20220402  06:30  09:20     319            1
# 6   HEL  ARN     807  20220402  20220402  10:00  11:00     319            1
# 7   ARN  HEL     808  20220402  20220402  11:40  12:40     319            1
# 8   HEL  BUD    1255  20220402  20220402  13:45  16:10     319            1
# 9   BUD  HEL    1256  20220402  20220402  17:00  19:20     319            1
# 10  HEL  BER    1431  20220403  20220403  04:25  06:25     319            1
# ...

# %%
df[((df["ORGN"] == "WAW") | (df["DSTN"] == "WAW")) & (df["DEPDT"] == 20220403)].head(5)
# Out:
# Empty DataFrame
# Columns: [ORGN, DSTN, FLTNUM, DEPDT, ARRDT, DEPTM, ARRTM, AC_TYPE, AIRCRAFT_ID, LINE]
# Index: []
