# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("s3://ay-rmp-home/nrm/bif/2023/05/INV_20230522.csv.gz")

# %%
df.head(5)
# Out:
#    CC  FLTNUM     DEPDT  DEPTM  DEPDT_UTC  DEPTM_UTC     ARRDT  ARRTM  \
# 0  AY       9  20230518   1600   20230518       1400  20230518   1725
# 1  AY       9  20230518   1600   20230518       1400  20230518   1725
# 2  AY       9  20230518   1600   20230518       1400  20230518   1725
# 3  AY      10  20230518   2130   20230519        330  20230519   1415
# 4  AY      10  20230518   2130   20230519        330  20230519   1415
#
#    ARRDT_UTC  ARRTM_UTC ORGN DSTN  DAYSPRIOR AIRCRAFT_TYPE CABIN  CAPS  CAPA  \
# 0   20230518       2325  HEL  ORD         -4           33S     J    28    28
# 1   20230518       2325  HEL  ORD         -4           33S     W    21    38
# 2   20230518       2325  HEL  ORD         -4           33S     Y   230   254
# 3   20230519       1215  ORD  HEL         -4           33S     J    28    28
# 4   20230519       1215  ORD  HEL         -4           33S     W    21    20
#
#    CAPO  CAPE  BKC  ETB  RC  EGS    AMR  RCR    ESB  SRC_DATE
# ...

# %%
df[
    (df["ORGN"] == "HEL") & 
    (df["DSTN"] == "BGO") &
    (df["DEPDT"] == 20230522)
]
# Out:
#        CC  FLTNUM     DEPDT  DEPTM  DEPDT_UTC  DEPTM_UTC     ARRDT  ARRTM  \
# 20723  AY     941  20230522   1605   20230522       1405  20230522   1720
# 20724  AY     941  20230522   1605   20230522       1405  20230522   1720
# 20734  AY     943  20230522    710   20230522        510  20230522    840
#
#        ARRDT_UTC  ARRTM_UTC ORGN DSTN  DAYSPRIOR AIRCRAFT_TYPE CABIN  CAPS  \
# 20723   20230522       1620  HEL  BGO          0           WF8     J     6
# 20724   20230522       1620  HEL  BGO          0           WF8     Y    72
# 20734   20230522        740  HEL  BGO          0           A70     Y    70
#
#        CAPA  CAPO  CAPE  BKC  ETB  RC  EGS    AMR  RCR     ESB  SRC_DATE
# 20723     5     6     5    1    1  RY    0  100.0  0.0   1.000  20230522
# 20724    76    72    76   73   71  RY    0  100.0  4.3  69.861  20230522
# 20734    70    70    70   67   64  RY    0  100.0  4.3  64.119  20230522
