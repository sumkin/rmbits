# %%
import matplotlib.pyplot as plt

# Data
num_changes = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]
profit = [-9602989.760698855, -8924573.830998063, -8560692.041879624, -8315100.761392415, 
          -8101993.640306354, -7886501.682165891, -7701899.809549421, -7546574.008939236, 
          -7406696.041239679, -7278987.047084421, -7159245.49303022, -7051374.016984999, 
          -6944072.418792605, -6845796.130065709, -6758784.922873616, -6673850.0897021, 
          -6594563.11798048, -6519041.474368334, -6447699.7388556, -6382346.117073506]

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(num_changes, profit, marker='o', linewidth=2, markersize=6, color='blue', markerfacecolor='red')
plt.xlabel('Number of Changes')
plt.ylabel('Profit')
plt.title('Profit vs Number of Changes')
plt.grid(True, alpha=0.3)

# Format y-axis to show values in millions
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Data
#       4 num_changes = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]
#
# ModuleNotFoundError: No module named 'matplotlib'
