# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('max_colwidth', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/bof/2023/05/BKG_OD_20230522.csv.gz", low_memory = False)

# %%
subdf = df[
    (df["BASE_OD_DEPT_DATE"] >= 20230601) &
    (df["BASE_OD_DEPT_DATE"] < 20230701)
]

# %%
subdf["YIELD"].sum()
# Out:
# 188752547.0
