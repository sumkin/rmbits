# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_columns', None)

# %%
ps = [2500.0, 2322.0, 1763.0, 1480.0]
aDs = [0.28, 0.29, 0.41, 0.531773]
fig = go.Figure(data=go.Scatter(x=ps, y=aDs))
fig.show()
