# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/bif/2023/05/INV_20230501.csv.gz")

# %%
df[
    (df["ORGN"] == "VBY") &
    (df["DSTN"] == "HEL")
].head(5)
# Out:
#        CC  FLTNUM     DEPDT  DEPTM  DEPDT_UTC  DEPTM_UTC     ARRDT  ARRTM  \
# 23589  AY     882  20230629    825   20230629        725  20230629   1040
# 23970  AY     882  20230701    825   20230701        725  20230701   1040
# 24191  AY     882  20230702   1330   20230702       1230  20230702   1545
# 24767  AY     882  20230622    825   20230622        725  20230622   1040
# 25132  AY     882  20230624    825   20230624        725  20230624   1040
#
#        ARRDT_UTC  ARRTM_UTC ORGN DSTN  DAYSPRIOR AIRCRAFT_TYPE CABIN  CAPS  \
# 23589   20230629        840  VBY  HEL         59           N7A     Y    68
# 23970   20230701        840  VBY  HEL         61           N7A     Y    68
# 24191   20230702       1345  VBY  HEL         62           N7A     Y    68
# 24767   20230622        840  VBY  HEL         52           A70     Y    70
# 25132   20230624        840  VBY  HEL         54           N7A     Y    68
#
# ...
