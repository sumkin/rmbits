# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/bff/2024/03/18/FCST_OD_20240318_20240618.csv.gz", low_memory=False)

# %%
df.head(5)
# Out:
#                                        GEO_OD_TS_KEY BASE_OD_ORGN  \
# 0  AGPHEL2024061820240618AY1676HELARN202406182024...          AGP
# 1  AGPHEL2024061820240618AY1676HELARN202406182024...          AGP
# 2  AGPHEL2024061820240618AY1676HELARN202406182024...          AGP
# 3  AGPHEL2024061820240618AY1676HELARN202406182024...          AGP
# 4  AGPHEL2024061820240618AY1676HELARN202406182024...          AGP
#
#   BASE_OD_DSTN BASE_OD_VIA BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION  \
# 0          ARN         HEL                   ES              EUROPE
# 1          ARN         HEL                   ES              EUROPE
# 2          ARN         HEL                   ES              EUROPE
# 3          ARN         HEL                   ES              EUROPE
# 4          ARN         HEL                   ES              EUROPE
#
#   BASE_OD_DSTN_COUNTRY BASE_OD_DSTN_REGION BASE_OPR_CC BASE_OPR_FLTNUM  \
# 0                   SE              EUROPE       AY-AY        1676-801
# ...
