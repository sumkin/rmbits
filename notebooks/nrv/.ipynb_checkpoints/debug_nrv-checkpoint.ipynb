# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/cf/2023/08/14/cf_prdt_sens_20230814_20230901.csv.gz")
# Out:
# /tmp/ipykernel_3621928/4196633477.py:1: DtypeWarning: Columns (17,19,20,21,22,23,24,26,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("s3://ay-emr-job/nrm/cf/2023/08/14/cf_prdt_sens_20230814_20230901.csv.gz")

# %%
df[df["DUAL"] > 0.0].head(5)
# Out:
# Empty DataFrame
# Columns: [GEO_OD_TS_KEY, BASE_OD_ORGN, BASE_OD_DSTN, BASE_OD_VIA, BASE_OD_ORGN_COUNTRY, BASE_OD_ORGN_REGION, BASE_OD_DSTN_COUNTRY, BASE_OD_DSTN_REGION, BASE_OPR_CC, BASE_OPR_FLTNUM, BASE_MKT_CC, BASE_MKT_FLTNUM, BASE_OD_DEPT_DATE, BASE_SEG_DEP_DATE, BASE_SEG_ARR_DATE, GEO_ORGN, GEO_DSTN, PREV_VIA, PREV_OPR_CC, PREV_OPR_FLTNUM, PREV_MKT_CC, PREV_MKT_FLTNUM, PREV_SEG_DEP_DATE, PREV_SEG_ARR_DATE, NEXT_VIA, NEXT_OPR_CC, NEXT_OPR_FLTNUM, NEXT_MKT_CC, NEXT_MKT_FLTNUM, NEXT_SEG_DEP_DATE, NEXT_SEG_ARR_DATE, POS, BC, FF, TP, CABIN, DUAL, LOW, HIGH, SRC_DATE]
# Index: []
#
# [0 rows x 40 columns]

# %%
df["DUAL"].head(10)

# %%
print("Hello")
# Out:
# Hello
