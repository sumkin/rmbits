# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/fdc/2024/04/22/fdc_20240422_20240517.csv.gz", low_memory=False)

# %%
df[
    (df["BASE_OD_ORGN"] == "JFK") &
    (df["BASE_OD_DSTN"] == "TLL")
].head(10)
# Out:
#                                             GEO_OD_TS_KEY BASE_OD_ORGN  \
# 358112  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358113  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358114  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358115  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358116  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358117  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358118  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358119  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358120  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
# 358121  JFKHEL2024051720240518AY0016HELTLL202405192024...          JFK
#
#        BASE_OD_DSTN BASE_OD_VIA BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION  \
# 358112          TLL         HEL                   US               NAMER
# ...
