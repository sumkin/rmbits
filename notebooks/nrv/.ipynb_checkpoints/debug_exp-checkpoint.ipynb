# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/expdmd/2023/12/04/expdmd_20231204_20240703.csv.gz")

# %%
df[df["AW"] < 0].head(10)
# Out:
#                                            GEO_OD_TS_KEY BASE_OD_ORGN  \
# 7966   BKKHEL2024070320240703AY0142HELVNO202407032024...          BKK
# 12343  CPHHEL2024070320240703AY0952HELLAX202407032024...          CPH
# 13796  CPHHEL2024070320240703AY0966HELJFK202407032024...          CPH
# 30030  ICNHEL2024070320240704AY0042HELCDG202407042024...          ICN
#
#       BASE_OD_DSTN  POS TP   FF        SV         SW            AV    AW
# 7966           VNO   LT  L  EAW  0.000335       -inf  1.125352e-07 -64.0
# 12343          LAX   US  B  UEW  0.006268       -inf  6.268000e-03  -inf
# 13796          JFK   DK  L  UEW       NaN        NaN  1.125352e-07  -inf
# 30030          CDG  ROW  L  EAW  0.004889  174.08918  1.125352e-07 -64.0
