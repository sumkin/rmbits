# %%
import pandas as pd

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/nrv_pwl/2024/05/06/nrv_pwl_20240506_20241028.csv.gz")

# %%
df[
    (df["BASE_OD_ORGN"] == "FUE") &
    (df["BASE_OD_DSTN"] == "HEL")
].head(5)
# Out:
#                       GEO_OD_TS_KEY BASE_OD_ORGN BASE_OD_DSTN BASE_OD_VIA  \
# 61360  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61361  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61362  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61363  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61364  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
#
#       BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION BASE_OD_DSTN_COUNTRY  \
# 61360                   ES              EUROPE                   FI
# 61361                   ES              EUROPE                   FI
# 61362                   ES              EUROPE                   FI
# 61363                   ES              EUROPE                   FI
# 61364                   ES              EUROPE                   FI
#
#       BASE_OD_DSTN_REGION BASE_OPR_CC BASE_OPR_FLTNUM  ... NEXT_SEG_DEP_DATE  \
# ...

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/cf/2024/05/06/cf_20240506_20241028.csv.gz", low_memory=False)

# %%
df[
    (df["BASE_OD_ORGN"] == "FUE") &
    (df["BASE_OD_DSTN"] == "HEL")
].head(5)
# Out:
#                       GEO_OD_TS_KEY BASE_OD_ORGN BASE_OD_DSTN BASE_OD_VIA  \
# 61360  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61361  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61362  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61363  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 61364  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
#
#       BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION BASE_OD_DSTN_COUNTRY  \
# 61360                   ES              EUROPE                   FI
# 61361                   ES              EUROPE                   FI
# 61362                   ES              EUROPE                   FI
# 61363                   ES              EUROPE                   FI
# 61364                   ES              EUROPE                   FI
#
#       BASE_OD_DSTN_REGION BASE_OPR_CC BASE_OPR_FLTNUM  ... NEXT_SEG_DEP_DATE  \
# ...

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/fdc/2024/05/06/fdc_20240506_20241028.csv.gz", low_memory=False)

# %%
df[
    (df["BASE_OD_ORGN"] == "FUE") &
    (df["BASE_OD_DSTN"] == "HEL") &
    (df["BASE_OD_DEP_DATE"] == 20241028)
].head(5)
# Out:
#                        GEO_OD_TS_KEY BASE_OD_ORGN BASE_OD_DSTN BASE_OD_VIA  \
# 216476  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 216477  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 216478  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 216479  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
# 216480  FUEHEL2024102820241028AY1702          FUE          HEL         NaN
#
#        BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION BASE_OD_DSTN_COUNTRY  \
# 216476                   ES              EUROPE                   FI
# 216477                   ES              EUROPE                   FI
# 216478                   ES              EUROPE                   FI
# 216479                   ES              EUROPE                   FI
# 216480                   ES              EUROPE                   FI
#
#        BASE_OD_DSTN_REGION BASE_OPR_CC BASE_OPR_FLTNUM  ... BC    FF  TP  \
# ...

# %%
df = pd.read_csv("s3://ay-emr-job/nrm/bff/2024/05/06/FCST_OD_20240506_20241028.csv.gz", low_memory=False)

# %%
df[
    (df["BASE_OD_ORGN"] == "FUE") &
    (df["BASE_OD_DSTN"] == "HEL") &
    (df["BASE_OD_DEP_DATE"] == 20241028)
].head(5)
# Out:
#                        GEO_OD_TS_KEY BASE_OD_ORGN BASE_OD_DSTN BASE_OD_VIA  \
# 217442  FUEHEL2024102820241029AY1702          FUE          HEL         NaN
# 217443  FUEHEL2024102820241029AY1702          FUE          HEL         NaN
# 217444  FUEHEL2024102820241029AY1702          FUE          HEL         NaN
# 217445  FUEHEL2024102820241029AY1702          FUE          HEL         NaN
# 217446  FUEHEL2024102820241029AY1702          FUE          HEL         NaN
#
#        BASE_OD_ORGN_COUNTRY BASE_OD_ORGN_REGION BASE_OD_DSTN_COUNTRY  \
# 217442                   ES              EUROPE                   FI
# 217443                   ES              EUROPE                   FI
# 217444                   ES              EUROPE                   FI
# 217445                   ES              EUROPE                   FI
# 217446                   ES              EUROPE                   FI
#
#        BASE_OD_DSTN_REGION BASE_OPR_CC BASE_OPR_FLTNUM  ...    SRGCCD  \
# ...
